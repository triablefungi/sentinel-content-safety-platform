# %% [markdown]
# # Sentinel DistilBERT Training
# Fine-tune and evaluate the transformer toxicity classifier on a Colab GPU.

# %%
# !nvidia-smi
import torch
print('CUDA available:', torch.cuda.is_available())

# %%
# !git clone https://github.com/triablefungi/sentinel-content-safety-platform.git
# %cd sentinel-content-safety-platform
# !python -m pip install -e '.[ml,transformer]'

# %%
# !python scripts/download_data.py --sample-size 20000

# %%
# !python scripts/train_transformer.py --epochs 2 --batch-size 16

# %%
import json
from pathlib import Path
metrics = json.loads(Path('artifacts/metrics/transformer_metrics.json').read_text())
metrics

# %%
# !zip -qr sentinel-transformer-artifacts.zip artifacts/models/transformer_toxicity artifacts/metrics/transformer_metrics.json
from google.colab import files
files.download('sentinel-transformer-artifacts.zip')
